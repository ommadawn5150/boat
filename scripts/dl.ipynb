# %%
# 開始日と終了日を指定(YYYY-MM-DD)
START_DATE = "2021-12-30"
END_DATE = "2022-11-23"


SAVE_DIR_K = "../DL/results_lzh/"
SAVE_DIR_B = "../DL/bangumi_lzh/"

# リクエスト間隔を指定(秒)　※サーバに負荷をかけないよう3秒以上を推奨
INTERVAL = 2

# URLの固定部分を指定
FIXED_URL_K = "http://www1.mbrace.or.jp/od2/K/"
FIXED_URL_B = "http://www1.mbrace.or.jp/od2/B/"

# 時間を制御する time モジュールをインポート
from time import sleep

# HTTP通信ライブラリの requests モジュールをインポート
from requests import get

# 日付を扱うための datetime モジュールをインポート
from datetime import datetime as dt
from datetime import timedelta as td

# フォルダ(ディレクトリ)を作成する makedirs モジュールをインポート
from os import makedirs
def DL_DATA(START_DATE, END_DATE, SAVE_DIR, INTERVAL, FIXED_URL, BK):
    # 開始合図
    print("作業を開始します")

    # ファイルを格納するフォルダを作成
    makedirs(SAVE_DIR, exist_ok=True)

    # 開始日と終了日を日付型に変換して格納
    start_date = dt.strptime(START_DATE, '%Y-%m-%d')
    end_date = dt.strptime(END_DATE, '%Y-%m-%d')

    # 日付の差から期間を計算
    days_num = (end_date - start_date).days + 1

    # 日付リストを格納する変数
    date_list = []

    # 日付リストを生成
    for i in range(days_num):
        # 開始日から日付を順に取得
        target_date = start_date + td(days=i)

        # 日付型を文字列に変換してリストに格納(YYYYMMDD)
        date_list.append(target_date.strftime("%Y%m%d"))

    # URL生成とダウンロード
    for date in date_list:

        # URL生成
        yyyymm = date[0:4] + date[4:6]
        yymmdd = date[2:4] + date[4:6] + date[6:8]

        variable_url = FIXED_URL + yyyymm + "/"+ BK + yymmdd + ".lzh"
        file_name = BK + yymmdd + ".lzh"

        # ダウンロード
        r = get(variable_url)

        # 成功した場合
        if r.status_code == 200:
            f = open(SAVE_DIR + file_name, 'wb')
            f.write(r.content)
            f.close()
            print(variable_url + " をダウンロードしました")

        # 失敗した場合
        else:
            print(variable_url + " のダウンロードに失敗しました")

        # 指定した間隔をあける
        sleep(INTERVAL)

    # 終了合図
    print("作業を終了しました")

# %%
DL_DATA(START_DATE, END_DATE, SAVE_DIR_K, INTERVAL, FIXED_URL_K, BK='k')
# Out:
# 作業を開始します
# http://www1.mbrace.or.jp/od2/K/202112/k211230.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202112/k211231.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220101.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220102.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220103.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220104.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220105.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220106.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220107.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220108.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220109.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220110.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220111.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220112.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220113.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220114.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220115.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220116.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220117.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220118.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220119.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220120.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220121.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220122.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220123.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220124.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220125.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220126.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220127.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220128.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220129.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220130.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202201/k220131.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220201.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220202.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220203.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220204.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220205.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220206.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220207.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220208.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220209.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220210.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220211.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220212.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220213.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220214.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220215.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220216.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220217.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220218.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220219.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220220.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220221.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220222.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220223.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220224.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220225.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220226.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220227.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202202/k220228.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220301.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220302.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220303.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220304.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220305.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220306.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220307.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220308.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220309.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220310.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220311.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220312.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220313.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220314.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220315.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220316.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220317.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220318.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220319.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220320.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220321.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220322.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220323.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220324.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220325.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220326.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220327.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220328.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220329.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220330.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202203/k220331.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220401.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220402.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220403.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220404.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220405.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220406.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220407.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220408.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220409.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220410.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220411.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220412.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220413.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220414.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220415.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220416.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220417.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220418.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220419.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220420.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220421.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220422.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220423.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220424.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220425.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220426.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220427.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220428.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220429.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202204/k220430.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220501.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220502.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220503.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220504.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220505.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220506.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220507.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220508.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220509.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220510.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220511.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220512.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220513.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220514.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220515.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220516.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220517.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220518.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220519.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220520.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220521.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220522.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220523.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220524.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220525.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220526.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220527.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220528.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220529.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220530.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202205/k220531.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220601.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220602.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220603.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220604.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220605.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220606.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220607.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220608.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220609.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220610.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220611.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220612.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220613.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220614.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220615.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220616.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220617.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220618.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220619.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220620.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220621.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220622.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220623.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220624.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220625.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220626.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220627.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220628.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220629.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202206/k220630.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220701.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220702.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220703.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220704.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220705.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220706.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220707.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220708.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220709.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220710.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220711.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220712.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220713.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220714.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220715.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220716.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220717.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220718.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220719.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220720.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220721.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220722.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220723.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220724.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220725.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220726.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220727.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220728.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220729.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220730.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202207/k220731.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220801.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220802.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220803.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220804.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220805.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220806.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220807.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220808.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220809.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220810.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220811.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220812.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220813.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220814.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220815.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220816.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220817.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220818.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220819.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220820.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220821.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220822.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220823.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220824.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220825.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220826.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220827.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220828.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220829.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220830.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202208/k220831.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220901.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220902.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220903.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220904.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220905.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220906.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220907.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220908.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220909.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220910.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220911.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220912.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220913.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220914.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220915.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220916.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220917.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220918.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220919.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220920.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220921.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220922.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220923.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220924.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220925.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220926.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220927.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220928.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220929.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202209/k220930.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221001.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221002.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221003.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221004.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221005.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221006.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221007.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221008.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221009.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221010.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221011.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221012.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221013.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221014.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221015.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221016.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221017.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221018.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221019.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221020.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221021.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221022.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221023.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221024.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221025.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221026.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221027.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221028.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221029.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221030.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202210/k221031.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221101.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221102.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221103.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221104.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221105.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221106.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221107.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221108.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221109.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221110.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221111.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221112.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221113.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221114.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221115.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221116.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221117.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221118.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221119.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221120.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221121.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221122.lzh をダウンロードしました
# http://www1.mbrace.or.jp/od2/K/202211/k221123.lzh をダウンロードしました
# 作業を終了しました

# %%
DL_DATA(START_DATE, END_DATE, SAVE_DIR_B, INTERVAL, FIXED_URL_B, BK='b')
# Out:
# 作業を開始します
# http://www1.mbrace.or.jp/od2/B/202211/b221123.lzh をダウンロードしました
# 作業を終了しました

# %%
# ダウンロードしたLZHファイルが保存されている場所を指定
LZH_FILE_DIR = "../DL/results_lzh_k/"
UNLZH_FILE_DIR = "../DL/un_lzh/"

makedirs(UNLZH_FILE_DIR,exist_ok=True)
# 解凍したファイルを保存する場所を指定
TXT_FILE_DIR = "../data/"
makedirs(TXT_FILE_DIR, exist_ok=True)
# 正規表現をサポートするモジュール re をインポート
import re

# LZH形式のファイルを解凍するパッケージ lhafile をインポート
import lhafile

# オペレーティングシステムの機能を利用するパッケージ os をインポート
import os
import shutil

def un_lzh(SAVE_DIR, TXT_FILE_DIR, UNLZH_FILE_DIR):
    # 開始合図
    print("作業を開始します")

    # ファイルを格納するフォルダを作成

    # LZHファイルのリストを取得
    lzh_file_list = os.listdir(SAVE_DIR)

    # ファイルの数だけ処理を繰り返す
    for lzh_file_name in lzh_file_list:

        # 拡張子が lzh のファイルに対してのみ実行
        if re.search(".lzh", lzh_file_name):

            file = lhafile.Lhafile(SAVE_DIR + lzh_file_name)

            # 解凍したファイルの名前を取得
            info = file.infolist()
            name = info[0].filename

            # 解凍したファイルの保存
            open(TXT_FILE_DIR + name, "wb").write(file.read(name))
            # 解凍前のファイルを移動
            shutil.move(SAVE_DIR + lzh_file_name , UNLZH_FILE_DIR + lzh_file_name)
            print(TXT_FILE_DIR + lzh_file_name + " を解凍しました")

    # 終了合図
    print("作業を終了しました")

# %%
un_lzh(SAVE_DIR_B, TXT_FILE_DIR, UNLZH_FILE_DIR)
# Out:
# 作業を開始します
# ../data/b221123.lzh を解凍しました
# 作業を終了しました

# %%
un_lzh(SAVE_DIR_K, TXT_FILE_DIR, UNLZH_FILE_DIR)
# Out:
# 作業を開始します
# ../data/k210703.lzh を解凍しました
# ../data/k220818.lzh を解凍しました
# ../data/k210717.lzh を解凍しました
# ../data/k220824.lzh を解凍しました
# ../data/k220830.lzh を解凍しました
# ../data/k210918.lzh を解凍しました
# ../data/k220603.lzh を解凍しました
# ../data/k220617.lzh を解凍しました
# ../data/k210924.lzh を解凍しました
# ../data/k210930.lzh を解凍しました
# ../data/k210501.lzh を解凍しました
# ../data/k200712.lzh を解凍しました
# ../data/k210515.lzh を解凍しました
# ../data/k200706.lzh を解凍しました
# ../data/k210529.lzh を解凍しました
# ../data/k220401.lzh を解凍しました
# ../data/k200909.lzh を解凍しました
# ../data/k220415.lzh を解凍しました
# ../data/k220429.lzh を解凍しました
# ../data/k200921.lzh を解凍しました
# ../data/k210313.lzh を解凍しました
# ../data/k211019.lzh を解凍しました
# ../data/k210307.lzh を解凍しました
# ../data/k201222.lzh を解凍しました
# ../data/k211031.lzh を解凍しました
# ../data/k211025.lzh を解凍しました
# ../data/k220213.lzh を解凍しました
# ../data/k220207.lzh を解凍しました
# ../data/k221119.lzh を解凍しました
# ../data/k210111.lzh を解凍しました
# ../data/k210105.lzh を解凍しました
# ../data/k201008.lzh を解凍しました
# ../data/k201020.lzh を解凍しました
# ../data/k211227.lzh を解凍しました
# ../data/k211226.lzh を解凍しました
# ../data/k201021.lzh を解凍しました
# ../data/k201009.lzh を解凍しました
# ../data/k210104.lzh を解凍しました
# ../data/k210110.lzh を解凍しました
# ../data/k221118.lzh を解凍しました
# ../data/k220206.lzh を解凍しました
# ../data/k220212.lzh を解凍しました
# ../data/k211024.lzh を解凍しました
# ../data/k211030.lzh を解凍しました
# ../data/k201223.lzh を解凍しました
# ../data/k210306.lzh を解凍しました
# ../data/k211018.lzh を解凍しました
# ../data/k210312.lzh を解凍しました
# ../data/k200920.lzh を解凍しました
# ../data/k220428.lzh を解凍しました
# ../data/k220414.lzh を解凍しました
# ../data/k200908.lzh を解凍しました
# ../data/k210528.lzh を解凍しました
# ../data/k200707.lzh を解凍しました
# ../data/k210514.lzh を解凍しました
# ../data/k200713.lzh を解凍しました
# ../data/k210925.lzh を解凍しました
# ../data/k220616.lzh を解凍しました
# ../data/k220602.lzh を解凍しました
# ../data/k210919.lzh を解凍しました
# ../data/k220831.lzh を解凍しました
# ../data/k220825.lzh を解凍しました
# ../data/k210716.lzh を解凍しました
# ../data/k220819.lzh を解凍しました
# ../data/k210702.lzh を解凍しました
# ../data/k210714.lzh を解凍しました
# ../data/k210728.lzh を解凍しました
# ../data/k220827.lzh を解凍しました
# ../data/k220614.lzh を解凍しました
# ../data/k220628.lzh を解凍しました
# ../data/k210927.lzh を解凍しました
# ../data/k210516.lzh を解凍しました
# ../data/k200705.lzh を解凍しました
# ../data/k210502.lzh を解凍しました
# ../data/k200711.lzh を解凍しました
# ../data/k220416.lzh を解凍しました
# ../data/k220402.lzh を解凍しました
# ../data/k200922.lzh を解凍しました
# ../data/k201209.lzh を解凍しました
# ../data/k210304.lzh を解凍しました
# ../data/k210310.lzh を解凍しました
# ../data/k211026.lzh を解凍しました
# ../data/k201221.lzh を解凍しました
# ../data/k220204.lzh を解凍しました
# ../data/k220210.lzh を解凍しました
# ../data/k210106.lzh を解凍しました
# ../data/k211218.lzh を解凍しました
# ../data/k210112.lzh を解凍しました
# ../data/k211224.lzh を解凍しました
# ../data/k211230.lzh を解凍しました
# ../data/k201023.lzh を解凍しました
# ../data/k201022.lzh を解凍しました
# ../data/k211231.lzh を解凍しました
# ../data/k211225.lzh を解凍しました
# ../data/k210113.lzh を解凍しました
# ../data/k211219.lzh を解凍しました
# ../data/k210107.lzh を解凍しました
# ../data/k220211.lzh を解凍しました
# ../data/k220205.lzh を解凍しました
# ../data/k201220.lzh を解凍しました
# ../data/k211027.lzh を解凍しました
# ../data/k210311.lzh を解凍しました
# ../data/k210305.lzh を解凍しました
# ../data/k201208.lzh を解凍しました
# ../data/k200923.lzh を解凍しました
# ../data/k220403.lzh を解凍しました
# ../data/k220417.lzh を解凍しました
# ../data/k200710.lzh を解凍しました
# ../data/k210503.lzh を解凍しました
# ../data/k200704.lzh を解凍しました
# ../data/k210517.lzh を解凍しました
# ../data/k210926.lzh を解凍しました
# ../data/k220629.lzh を解凍しました
# ../data/k220601.lzh を解凍しました
# ../data/k220615.lzh を解凍しました
# ../data/k220826.lzh を解凍しました
# ../data/k210729.lzh を解凍しました
# ../data/k210701.lzh を解凍しました
# ../data/k210715.lzh を解凍しました
# ../data/k220822.lzh を解凍しました
# ../data/k210711.lzh を解凍しました
# ../data/k210705.lzh を解凍しました
# ../data/k210922.lzh を解凍しました
# ../data/k220611.lzh を解凍しました
# ../data/k220605.lzh を解凍しました
# ../data/k200728.lzh を解凍しました
# ../data/k210513.lzh を解凍しました
# ../data/k200714.lzh を解凍しました
# ../data/k210507.lzh を解凍しました
# ../data/k200927.lzh を解凍しました
# ../data/k220413.lzh を解凍しました
# ../data/k220407.lzh を解凍しました
# ../data/k211023.lzh を解凍しました
# ../data/k201230.lzh を解凍しました
# ../data/k201224.lzh を解凍しました
# ../data/k210329.lzh を解凍しました
# ../data/k210301.lzh を解凍しました
# ../data/k201218.lzh を解凍しました
# ../data/k210315.lzh を解凍しました
# ../data/k221123.lzh を解凍しました
# ../data/k220201.lzh を解凍しました
# ../data/k220215.lzh を解凍しました
# ../data/k211221.lzh を解凍しました
# ../data/k201026.lzh を解凍しました
# ../data/k210103.lzh を解凍しました
# ../data/k210117.lzh を解凍しました
# ../data/k211209.lzh を解凍しました
# ../data/k211208.lzh を解凍しました
# ../data/k210116.lzh を解凍しました
# ../data/k210102.lzh を解凍しました
# ../data/k201027.lzh を解凍しました
# ../data/k211220.lzh を解凍しました
# ../data/k220214.lzh を解凍しました
# ../data/k220228.lzh を解凍しました
# ../data/k221122.lzh を解凍しました
# ../data/k210314.lzh を解凍しました
# ../data/k201219.lzh を解凍しました
# ../data/k210328.lzh を解凍しました
# ../data/k201225.lzh を解凍しました
# ../data/k201231.lzh を解凍しました
# ../data/k211022.lzh を解凍しました
# ../data/k220406.lzh を解凍しました
# ../data/k220412.lzh を解凍しました
# ../data/k200926.lzh を解凍しました
# ../data/k210506.lzh を解凍しました
# ../data/k200715.lzh を解凍しました
# ../data/k210512.lzh を解凍しました
# ../data/k200701.lzh を解凍しました
# ../data/k200729.lzh を解凍しました
# ../data/k220604.lzh を解凍しました
# ../data/k220610.lzh を解凍しました
# ../data/k210923.lzh を解凍しました
# ../data/k210704.lzh を解凍しました
# ../data/k210710.lzh を解凍しました
# ../data/k220823.lzh を解凍しました
# ../data/k220821.lzh を解凍しました
# ../data/k210706.lzh を解凍しました
# ../data/k210712.lzh を解凍しました
# ../data/k220809.lzh を解凍しました
# ../data/k210921.lzh を解凍しました
# ../data/k220606.lzh を解凍しました
# ../data/k210909.lzh を解凍しました
# ../data/k220612.lzh を解凍しました
# ../data/k200717.lzh を解凍しました
# ../data/k210504.lzh を解凍しました
# ../data/k200703.lzh を解凍しました
# ../data/k210510.lzh を解凍しました
# ../data/k200930.lzh を解凍しました
# ../data/k200924.lzh を解凍しました
# ../data/k220404.lzh を解凍しました
# ../data/k220410.lzh を解凍しました
# ../data/k200918.lzh を解凍しました
# ../data/k201227.lzh を解凍しました
# ../data/k211020.lzh を解凍しました
# ../data/k211008.lzh を解凍しました
# ../data/k210316.lzh を解凍しました
# ../data/k210302.lzh を解凍しました
# ../data/k221120.lzh を解凍しました
# ../data/k220216.lzh を解凍しました
# ../data/k221108.lzh を解凍しました
# ../data/k220202.lzh を解凍しました
# ../data/k210128.lzh を解凍しました
# ../data/k201025.lzh を解凍しました
# ../data/k201031.lzh を解凍しました
# ../data/k211222.lzh を解凍しました
# ../data/k210114.lzh を解凍しました
# ../data/k201019.lzh を解凍しました
# ../data/k210101.lzh を解凍しました
# ../data/k201018.lzh を解凍しました
# ../data/k210115.lzh を解凍しました
# ../data/k211223.lzh を解凍しました
# ../data/k201030.lzh を解凍しました
# ../data/k201024.lzh を解凍しました
# ../data/k210129.lzh を解凍しました
# ../data/k220203.lzh を解凍しました
# ../data/k221109.lzh を解凍しました
# ../data/k220217.lzh を解凍しました
# ../data/k221121.lzh を解凍しました
# ../data/k210303.lzh を解凍しました
# ../data/k210317.lzh を解凍しました
# ../data/k211009.lzh を解凍しました
# ../data/k211021.lzh を解凍しました
# ../data/k201226.lzh を解凍しました
# ../data/k200919.lzh を解凍しました
# ../data/k220411.lzh を解凍しました
# ../data/k220405.lzh を解凍しました
# ../data/k200925.lzh を解凍しました
# ../data/k210511.lzh を解凍しました
# ../data/k200702.lzh を解凍しました
# ../data/k210505.lzh を解凍しました
# ../data/k200716.lzh を解凍しました
# ../data/k220613.lzh を解凍しました
# ../data/k210908.lzh を解凍しました
# ../data/k220607.lzh を解凍しました
# ../data/k210920.lzh を解凍しました
# ../data/k220808.lzh を解凍しました
# ../data/k210713.lzh を解凍しました
# ../data/k210707.lzh を解凍しました
# ../data/k220820.lzh を解凍しました
# ../data/k201123.lzh を解凍しました
# ../data/k220106.lzh を解凍しました
# ../data/k220112.lzh を解凍しました
# ../data/k210204.lzh を解凍しました
# ../data/k210210.lzh を解凍しました
# ../data/k211126.lzh を解凍しました
# ../data/k220304.lzh を解凍しました
# ../data/k220310.lzh を解凍しました
# ../data/k221026.lzh を解凍しました
# ../data/k210416.lzh を解凍しました
# ../data/k210402.lzh を解凍しました
# ../data/k220516.lzh を解凍しました
# ../data/k220502.lzh を解凍しました
# ../data/k200822.lzh を解凍しました
# ../data/k210614.lzh を解凍しました
# ../data/k210628.lzh を解凍しました
# ../data/k220927.lzh を解凍しました
# ../data/k220714.lzh を解凍しました
# ../data/k220728.lzh を解凍しました
# ../data/k210827.lzh を解凍しました
# ../data/k210826.lzh を解凍しました
# ../data/k220729.lzh を解凍しました
# ../data/k220701.lzh を解凍しました
# ../data/k220715.lzh を解凍しました
# ../data/k220926.lzh を解凍しました
# ../data/k210629.lzh を解凍しました
# ../data/k210601.lzh を解凍しました
# ../data/k210615.lzh を解凍しました
# ../data/k200823.lzh を解凍しました
# ../data/k220503.lzh を解凍しました
# ../data/k220517.lzh を解凍しました
# ../data/k210403.lzh を解凍しました
# ../data/k210417.lzh を解凍しました
# ../data/k221027.lzh を解凍しました
# ../data/k220311.lzh を解凍しました
# ../data/k220305.lzh を解凍しました
# ../data/k211127.lzh を解凍しました
# ../data/k210211.lzh を解凍しました
# ../data/k210205.lzh を解凍しました
# ../data/k220113.lzh を解凍しました
# ../data/k220107.lzh を解凍しました
# ../data/k201122.lzh を解凍しました
# ../data/k201108.lzh を解凍しました
# ../data/k201120.lzh を解凍しました
# ../data/k220111.lzh を解凍しました
# ../data/k220105.lzh を解凍しました
# ../data/k210213.lzh を解凍しました
# ../data/k210207.lzh を解凍しました
# ../data/k211119.lzh を解凍しました
# ../data/k211125.lzh を解凍しました
# ../data/k220313.lzh を解凍しました
# ../data/k221019.lzh を解凍しました
# ../data/k220307.lzh を解凍しました
# ../data/k221031.lzh を解凍しました
# ../data/k221025.lzh を解凍しました
# ../data/k210401.lzh を解凍しました
# ../data/k210415.lzh を解凍しました
# ../data/k210429.lzh を解凍しました
# ../data/k200809.lzh を解凍しました
# ../data/k220501.lzh を解凍しました
# ../data/k220515.lzh を解凍しました
# ../data/k200821.lzh を解凍しました
# ../data/k220529.lzh を解凍しました
# ../data/k220918.lzh を解凍しました
# ../data/k210603.lzh を解凍しました
# ../data/k210617.lzh を解凍しました
# ../data/k220924.lzh を解凍しました
# ../data/k220930.lzh を解凍しました
# ../data/k220703.lzh を解凍しました
# ../data/k210818.lzh を解凍しました
# ../data/k220717.lzh を解凍しました
# ../data/k210824.lzh を解凍しました
# ../data/k210830.lzh を解凍しました
# ../data/k210831.lzh を解凍しました
# ../data/k210825.lzh を解凍しました
# ../data/k220716.lzh を解凍しました
# ../data/k210819.lzh を解凍しました
# ../data/k220702.lzh を解凍しました
# ../data/k220925.lzh を解凍しました
# ../data/k210616.lzh を解凍しました
# ../data/k210602.lzh を解凍しました
# ../data/k220919.lzh を解凍しました
# ../data/k220528.lzh を解凍しました
# ../data/k200820.lzh を解凍しました
# ../data/k220514.lzh を解凍しました
# ../data/k200808.lzh を解凍しました
# ../data/k210428.lzh を解凍しました
# ../data/k210414.lzh を解凍しました
# ../data/k221024.lzh を解凍しました
# ../data/k221030.lzh を解凍しました
# ../data/k220306.lzh を解凍しました
# ../data/k221018.lzh を解凍しました
# ../data/k220312.lzh を解凍しました
# ../data/k211124.lzh を解凍しました
# ../data/k211130.lzh を解凍しました
# ../data/k211118.lzh を解凍しました
# ../data/k210206.lzh を解凍しました
# ../data/k210212.lzh を解凍しました
# ../data/k220104.lzh を解凍しました
# ../data/k220110.lzh を解凍しました
# ../data/k201121.lzh を解凍しました
# ../data/k201109.lzh を解凍しました
# ../data/k201125.lzh を解凍しました
# ../data/k201119.lzh を解凍しました
# ../data/k220128.lzh を解凍しました
# ../data/k220114.lzh を解凍しました
# ../data/k211120.lzh を解凍しました
# ../data/k210216.lzh を解凍しました
# ../data/k211108.lzh を解凍しました
# ../data/k210202.lzh を解凍しました
# ../data/k221020.lzh を解凍しました
# ../data/k221008.lzh を解凍しました
# ../data/k220316.lzh を解凍しました
# ../data/k220302.lzh を解凍しました
# ../data/k210404.lzh を解凍しました
# ../data/k210410.lzh を解凍しました
# ../data/k200830.lzh を解凍しました
# ../data/k200824.lzh を解凍しました
# ../data/k220504.lzh を解凍しました
# ../data/k200818.lzh を解凍しました
# ../data/k220510.lzh を解凍しました
# ../data/k220921.lzh を解凍しました
# ../data/k210606.lzh を解凍しました
# ../data/k220909.lzh を解凍しました
# ../data/k210612.lzh を解凍しました
# ../data/k210821.lzh を解凍しました
# ../data/k220706.lzh を解凍しました
# ../data/k220712.lzh を解凍しました
# ../data/k210809.lzh を解凍しました
# ../data/k210808.lzh を解凍しました
# ../data/k220713.lzh を解凍しました
# ../data/k220707.lzh を解凍しました
# ../data/k210820.lzh を解凍しました
# ../data/k210613.lzh を解凍しました
# ../data/k220908.lzh を解凍しました
# ../data/k210607.lzh を解凍しました
# ../data/k220920.lzh を解凍しました
# ../data/k220511.lzh を解凍しました
# ../data/k200819.lzh を解凍しました
# ../data/k220505.lzh を解凍しました
# ../data/k200825.lzh を解凍しました
# ../data/k200831.lzh を解凍しました
# ../data/k210411.lzh を解凍しました
# ../data/k210405.lzh を解凍しました
# ../data/k220303.lzh を解凍しました
# ../data/k220317.lzh を解凍しました
# ../data/k221009.lzh を解凍しました
# ../data/k221021.lzh を解凍しました
# ../data/k210203.lzh を解凍しました
# ../data/k211109.lzh を解凍しました
# ../data/k210217.lzh を解凍しました
# ../data/k211121.lzh を解凍しました
# ../data/k220101.lzh を解凍しました
# ../data/k220115.lzh を解凍しました
# ../data/k220129.lzh を解凍しました
# ../data/k201118.lzh を解凍しました
# ../data/k201130.lzh を解凍しました
# ../data/k201124.lzh を解凍しました
# ../data/k201126.lzh を解凍しました
# ../data/k220103.lzh を解凍しました
# ../data/k220117.lzh を解凍しました
# ../data/k211123.lzh を解凍しました
# ../data/k210201.lzh を解凍しました
# ../data/k210215.lzh を解凍しました
# ../data/k221023.lzh を解凍しました
# ../data/k220329.lzh を解凍しました
# ../data/k220301.lzh を解凍しました
# ../data/k220315.lzh を解凍しました
# ../data/k210413.lzh を解凍しました
# ../data/k210407.lzh を解凍しました
# ../data/k200827.lzh を解凍しました
# ../data/k220513.lzh を解凍しました
# ../data/k220507.lzh を解凍しました
# ../data/k220922.lzh を解凍しました
# ../data/k210611.lzh を解凍しました
# ../data/k210605.lzh を解凍しました
# ../data/k210822.lzh を解凍しました
# ../data/k220711.lzh を解凍しました
# ../data/k220705.lzh を解凍しました
# ../data/k220704.lzh を解凍しました
# ../data/k220710.lzh を解凍しました
# ../data/k210823.lzh を解凍しました
# ../data/k210604.lzh を解凍しました
# ../data/k210610.lzh を解凍しました
# ../data/k220923.lzh を解凍しました
# ../data/k220506.lzh を解凍しました
# ../data/k220512.lzh を解凍しました
# ../data/k200826.lzh を解凍しました
# ../data/k210406.lzh を解凍しました
# ../data/k210412.lzh を解凍しました
# ../data/k220314.lzh を解凍しました
# ../data/k220328.lzh を解凍しました
# ../data/k221022.lzh を解凍しました
# ../data/k210214.lzh を解凍しました
# ../data/k210228.lzh を解凍しました
# ../data/k211122.lzh を解凍しました
# ../data/k220116.lzh を解凍しました
# ../data/k220102.lzh を解凍しました
# ../data/k201127.lzh を解凍しました
# ../data/k201116.lzh を解凍しました
# ../data/k201102.lzh を解凍しました
# ../data/k220127.lzh を解凍しました
# ../data/k210225.lzh を解凍しました
# ../data/k210219.lzh を解凍しました
# ../data/k211107.lzh を解凍しました
# ../data/k211113.lzh を解凍しました
# ../data/k220325.lzh を解凍しました
# ../data/k220331.lzh を解凍しました
# ../data/k221007.lzh を解凍しました
# ../data/k220319.lzh を解凍しました
# ../data/k221013.lzh を解凍しました
# ../data/k210423.lzh を解凍しました
# ../data/k220523.lzh を解凍しました
# ../data/k200803.lzh を解凍しました
# ../data/k200817.lzh を解凍しました
# ../data/k210621.lzh を解凍しました
# ../data/k220912.lzh を解凍しました
# ../data/k210609.lzh を解凍しました
# ../data/k220906.lzh を解凍しました
# ../data/k220721.lzh を解凍しました
# ../data/k220709.lzh を解凍しました
# ../data/k210812.lzh を解凍しました
# ../data/k210806.lzh を解凍しました
# ../data/k210807.lzh を解凍しました
# ../data/k210813.lzh を解凍しました
# ../data/k220708.lzh を解凍しました
# ../data/k220720.lzh を解凍しました
# ../data/k220907.lzh を解凍しました
# ../data/k210608.lzh を解凍しました
# ../data/k220913.lzh を解凍しました
# ../data/k210620.lzh を解凍しました
# ../data/k200816.lzh を解凍しました
# ../data/k200802.lzh を解凍しました
# ../data/k220522.lzh を解凍しました
# ../data/k210422.lzh を解凍しました
# ../data/k221012.lzh を解凍しました
# ../data/k220318.lzh を解凍しました
# ../data/k221006.lzh を解凍しました
# ../data/k220330.lzh を解凍しました
# ../data/k220324.lzh を解凍しました
# ../data/k211112.lzh を解凍しました
# ../data/k211106.lzh を解凍しました
# ../data/k210218.lzh を解凍しました
# ../data/k210224.lzh を解凍しました
# ../data/k220126.lzh を解凍しました
# ../data/k201103.lzh を解凍しました
# ../data/k201117.lzh を解凍しました
# ../data/k201129.lzh を解凍しました
# ../data/k201101.lzh を解凍しました
# ../data/k201115.lzh を解凍しました
# ../data/k220130.lzh を解凍しました
# ../data/k220124.lzh を解凍しました
# ../data/k220118.lzh を解凍しました
# ../data/k210226.lzh を解凍しました
# ../data/k211110.lzh を解凍しました
# ../data/k211104.lzh を解凍しました
# ../data/k220326.lzh を解凍しました
# ../data/k221010.lzh を解凍しました
# ../data/k221004.lzh を解凍しました
# ../data/k210420.lzh を解凍しました
# ../data/k210408.lzh を解凍しました
# ../data/k200828.lzh を解凍しました
# ../data/k220520.lzh を解凍しました
# ../data/k200814.lzh を解凍しました
# ../data/k220508.lzh を解凍しました
# ../data/k210622.lzh を解凍しました
# ../data/k220905.lzh を解凍しました
# ../data/k220911.lzh を解凍しました
# ../data/k220722.lzh を解凍しました
# ../data/k210805.lzh を解凍しました
# ../data/k210811.lzh を解凍しました
# ../data/k210810.lzh を解凍しました
# ../data/k210804.lzh を解凍しました
# ../data/k220723.lzh を解凍しました
# ../data/k220910.lzh を解凍しました
# ../data/k220904.lzh を解凍しました
# ../data/k210623.lzh を解凍しました
# ../data/k220509.lzh を解凍しました
# ../data/k200801.lzh を解凍しました
# ../data/k200815.lzh を解凍しました
# ../data/k220521.lzh を解凍しました
# ../data/k200829.lzh を解凍しました
# ../data/k210409.lzh を解凍しました
# ../data/k210421.lzh を解凍しました
# ../data/k221005.lzh を解凍しました
# ../data/k221011.lzh を解凍しました
# ../data/k220327.lzh を解凍しました
# ../data/k211105.lzh を解凍しました
# ../data/k211111.lzh を解凍しました
# ../data/k210227.lzh を解凍しました
# ../data/k220119.lzh を解凍しました
# ../data/k220125.lzh を解凍しました
# ../data/k220131.lzh を解凍しました
# ../data/k201114.lzh を解凍しました
# ../data/k201128.lzh を解凍しました
# ../data/k201104.lzh を解凍しました
# ../data/k201110.lzh を解凍しました
# ../data/k220109.lzh を解凍しました
# ../data/k220121.lzh を解凍しました
# ../data/k211115.lzh を解凍しました
# ../data/k211101.lzh を解凍しました
# ../data/k211129.lzh を解凍しました
# ../data/k210223.lzh を解凍しました
# ../data/k221015.lzh を解凍しました
# ../data/k221001.lzh を解凍しました
# ../data/k221029.lzh を解凍しました
# ../data/k220323.lzh を解凍しました
# ../data/k210419.lzh を解凍しました
# ../data/k210425.lzh を解凍しました
# ../data/k200811.lzh を解凍しました
# ../data/k220519.lzh を解凍しました
# ../data/k200805.lzh を解凍しました
# ../data/k220525.lzh を解凍しました
# ../data/k220531.lzh を解凍しました
# ../data/k220914.lzh を解凍しました
# ../data/k210627.lzh を解凍しました
# ../data/k220928.lzh を解凍しました
# ../data/k210814.lzh を解凍しました
# ../data/k220727.lzh を解凍しました
# ../data/k210828.lzh を解凍しました
# ../data/k210829.lzh を解凍しました
# ../data/k220726.lzh を解凍しました
# ../data/k210815.lzh を解凍しました
# ../data/k210801.lzh を解凍しました
# ../data/k220929.lzh を解凍しました
# ../data/k210626.lzh を解凍しました
# ../data/k220915.lzh を解凍しました
# ../data/k220901.lzh を解凍しました
# ../data/k220530.lzh を解凍しました
# ../data/k220524.lzh を解凍しました
# ../data/k200804.lzh を解凍しました
# ../data/k220518.lzh を解凍しました
# ../data/k200810.lzh を解凍しました
# ../data/k210430.lzh を解凍しました
# ../data/k210424.lzh を解凍しました
# ../data/k210418.lzh を解凍しました
# ../data/k220322.lzh を解凍しました
# ../data/k221028.lzh を解凍しました
# ../data/k221014.lzh を解凍しました
# ../data/k210222.lzh を解凍しました
# ../data/k211128.lzh を解凍しました
# ../data/k211114.lzh を解凍しました
# ../data/k220120.lzh を解凍しました
# ../data/k220108.lzh を解凍しました
# ../data/k201111.lzh を解凍しました
# ../data/k201105.lzh を解凍しました
# ../data/k201113.lzh を解凍しました
# ../data/k201107.lzh を解凍しました
# ../data/k220122.lzh を解凍しました
# ../data/k211102.lzh を解凍しました
# ../data/k210208.lzh を解凍しました
# ../data/k211116.lzh を解凍しました
# ../data/k210220.lzh を解凍しました
# ../data/k221002.lzh を解凍しました
# ../data/k221016.lzh を解凍しました
# ../data/k220308.lzh を解凍しました
# ../data/k220320.lzh を解凍しました
# ../data/k210426.lzh を解凍しました
# ../data/k200806.lzh を解凍しました
# ../data/k200812.lzh を解凍しました
# ../data/k220526.lzh を解凍しました
# ../data/k220917.lzh を解凍しました
# ../data/k220903.lzh を解凍しました
# ../data/k210618.lzh を解凍しました
# ../data/k210630.lzh を解凍しました
# ../data/k210624.lzh を解凍しました
# ../data/k210817.lzh を解凍しました
# ../data/k220718.lzh を解凍しました
# ../data/k210803.lzh を解凍しました
# ../data/k220730.lzh を解凍しました
# ../data/k220724.lzh を解凍しました
# ../data/k220725.lzh を解凍しました
# ../data/k220731.lzh を解凍しました
# ../data/k210802.lzh を解凍しました
# ../data/k220719.lzh を解凍しました
# ../data/k210816.lzh を解凍しました
# ../data/k210625.lzh を解凍しました
# ../data/k210619.lzh を解凍しました
# ../data/k220902.lzh を解凍しました
# ../data/k220916.lzh を解凍しました
# ../data/k220527.lzh を解凍しました
# ../data/k200813.lzh を解凍しました
# ../data/k200807.lzh を解凍しました
# ../data/k210427.lzh を解凍しました
# ../data/k220321.lzh を解凍しました
# ../data/k220309.lzh を解凍しました
# ../data/k221017.lzh を解凍しました
# ../data/k221003.lzh を解凍しました
# ../data/k210221.lzh を解凍しました
# ../data/k211117.lzh を解凍しました
# ../data/k210209.lzh を解凍しました
# ../data/k211103.lzh を解凍しました
# ../data/k220123.lzh を解凍しました
# ../data/k201106.lzh を解凍しました
# ../data/k201112.lzh を解凍しました
# ../data/k210722.lzh を解凍しました
# ../data/k220805.lzh を解凍しました
# ../data/k220811.lzh を解凍しました
# ../data/k220622.lzh を解凍しました
# ../data/k210905.lzh を解凍しました
# ../data/k210911.lzh を解凍しました
# ../data/k210520.lzh を解凍しました
# ../data/k200727.lzh を解凍しました
# ../data/k210508.lzh を解凍しました
# ../data/k220420.lzh を解凍しました
# ../data/k200928.lzh を解凍しました
# ../data/k200914.lzh を解凍しました
# ../data/k220408.lzh を解凍しました
# ../data/k210326.lzh を解凍しました
# ../data/k201203.lzh を解凍しました
# ../data/k211010.lzh を解凍しました
# ../data/k201217.lzh を解凍しました
# ../data/k211004.lzh を解凍しました
# ../data/k220226.lzh を解凍しました
# ../data/k221110.lzh を解凍しました
# ../data/k221104.lzh を解凍しました
# ../data/k210130.lzh を解凍しました
# ../data/k210124.lzh を解凍しました
# ../data/k201029.lzh を解凍しました
# ../data/k211212.lzh を解凍しました
# ../data/k201001.lzh を解凍しました
# ../data/k210118.lzh を解凍しました
# ../data/k211206.lzh を解凍しました
# ../data/k201015.lzh を解凍しました
# ../data/k201014.lzh を解凍しました
# ../data/k211207.lzh を解凍しました
# ../data/k210119.lzh を解凍しました
# ../data/k211213.lzh を解凍しました
# ../data/k201028.lzh を解凍しました
# ../data/k210125.lzh を解凍しました
# ../data/k210131.lzh を解凍しました
# ../data/k221105.lzh を解凍しました
# ../data/k221111.lzh を解凍しました
# ../data/k220227.lzh を解凍しました
# ../data/k211005.lzh を解凍しました
# ../data/k201216.lzh を解凍しました
# ../data/k211011.lzh を解凍しました
# ../data/k201202.lzh を解凍しました
# ../data/k210327.lzh を解凍しました
# ../data/k200901.lzh を解凍しました
# ../data/k220409.lzh を解凍しました
# ../data/k200915.lzh を解凍しました
# ../data/k200929.lzh を解凍しました
# ../data/k220421.lzh を解凍しました
# ../data/k210509.lzh を解凍しました
# ../data/k200726.lzh を解凍しました
# ../data/k210521.lzh を解凍しました
# ../data/k210910.lzh を解凍しました
# ../data/k210904.lzh を解凍しました
# ../data/k220623.lzh を解凍しました
# ../data/k220810.lzh を解凍しました
# ../data/k220804.lzh を解凍しました
# ../data/k210723.lzh を解凍しました
# ../data/k210721.lzh を解凍しました
# ../data/k210709.lzh を解凍しました
# ../data/k220812.lzh を解凍しました
# ../data/k220806.lzh を解凍しました
# ../data/k220621.lzh を解凍しました
# ../data/k210912.lzh を解凍しました
# ../data/k220609.lzh を解凍しました
# ../data/k210906.lzh を解凍しました
# ../data/k200724.lzh を解凍しました
# ../data/k210523.lzh を解凍しました
# ../data/k200730.lzh を解凍しました
# ../data/k200718.lzh を解凍しました
# ../data/k220423.lzh を解凍しました
# ../data/k200903.lzh を解凍しました
# ../data/k200917.lzh を解凍しました
# ../data/k201228.lzh を解凍しました
# ../data/k210325.lzh を解凍しました
# ../data/k210331.lzh を解凍しました
# ../data/k201214.lzh を解凍しました
# ../data/k211007.lzh を解凍しました
# ../data/k210319.lzh を解凍しました
# ../data/k211013.lzh を解凍しました
# ../data/k220225.lzh を解凍しました
# ../data/k220219.lzh を解凍しました
# ../data/k221107.lzh を解凍しました
# ../data/k221113.lzh を解凍しました
# ../data/k210127.lzh を解凍しました
# ../data/k211205.lzh を解凍しました
# ../data/k201016.lzh を解凍しました
# ../data/k211211.lzh を解凍しました
# ../data/k201002.lzh を解凍しました
# ../data/k201003.lzh を解凍しました
# ../data/k211210.lzh を解凍しました
# ../data/k201017.lzh を解凍しました
# ../data/k211204.lzh を解凍しました
# ../data/k210126.lzh を解凍しました
# ../data/k221112.lzh を解凍しました
# ../data/k221106.lzh を解凍しました
# ../data/k220218.lzh を解凍しました
# ../data/k220224.lzh を解凍しました
# ../data/k211012.lzh を解凍しました
# ../data/k201201.lzh を解凍しました
# ../data/k210318.lzh を解凍しました
# ../data/k211006.lzh を解凍しました
# ../data/k201215.lzh を解凍しました
# ../data/k210330.lzh を解凍しました
# ../data/k210324.lzh を解凍しました
# ../data/k201229.lzh を解凍しました
# ../data/k200916.lzh を解凍しました
# ../data/k200902.lzh を解凍しました
# ../data/k220422.lzh を解凍しました
# ../data/k200719.lzh を解凍しました
# ../data/k200731.lzh を解凍しました
# ../data/k210522.lzh を解凍しました
# ../data/k200725.lzh を解凍しました
# ../data/k210907.lzh を解凍しました
# ../data/k220608.lzh を解凍しました
# ../data/k210913.lzh を解凍しました
# ../data/k220620.lzh を解凍しました
# ../data/k220807.lzh を解凍しました
# ../data/k220813.lzh を解凍しました
# ../data/k210708.lzh を解凍しました
# ../data/k210720.lzh を解凍しました
# ../data/k220817.lzh を解凍しました
# ../data/k210718.lzh を解凍しました
# ../data/k220803.lzh を解凍しました
# ../data/k210730.lzh を解凍しました
# ../data/k210724.lzh を解凍しました
# ../data/k210917.lzh を解凍しました
# ../data/k210903.lzh を解凍しました
# ../data/k220618.lzh を解凍しました
# ../data/k220630.lzh を解凍しました
# ../data/k220624.lzh を解凍しました
# ../data/k200709.lzh を解凍しました
# ../data/k200721.lzh を解凍しました
# ../data/k210526.lzh を解凍しました
# ../data/k200906.lzh を解凍しました
# ../data/k200912.lzh を解凍しました
# ../data/k220426.lzh を解凍しました
# ../data/k211002.lzh を解凍しました
# ../data/k201211.lzh を解凍しました
# ../data/k211016.lzh を解凍しました
# ../data/k201205.lzh を解凍しました
# ../data/k210308.lzh を解凍しました
# ../data/k210320.lzh を解凍しました
# ../data/k221102.lzh を解凍しました
# ../data/k220208.lzh を解凍しました
# ../data/k221116.lzh を解凍しました
# ../data/k220220.lzh を解凍しました
# ../data/k201013.lzh を解凍しました
# ../data/k201007.lzh を解凍しました
# ../data/k211214.lzh を解凍しました
# ../data/k210122.lzh を解凍しました
# ../data/k211228.lzh を解凍しました
# ../data/k211229.lzh を解凍しました
# ../data/k210123.lzh を解凍しました
# ../data/k211215.lzh を解凍しました
# ../data/k201006.lzh を解凍しました
# ../data/k211201.lzh を解凍しました
# ../data/k201012.lzh を解凍しました
# ../data/k220221.lzh を解凍しました
# ../data/k221117.lzh を解凍しました
# ../data/k220209.lzh を解凍しました
# ../data/k221103.lzh を解凍しました
# ../data/k210321.lzh を解凍しました
# ../data/k210309.lzh を解凍しました
# ../data/k201204.lzh を解凍しました
# ../data/k211017.lzh を解凍しました
# ../data/k201210.lzh を解凍しました
# ../data/k211003.lzh を解凍しました
# ../data/k220427.lzh を解凍しました
# ../data/k200913.lzh を解凍しました
# ../data/k200907.lzh を解凍しました
# ../data/k210527.lzh を解凍しました
# ../data/k200720.lzh を解凍しました
# ../data/k200708.lzh を解凍しました
# ../data/k220625.lzh を解凍しました
# ../data/k220619.lzh を解凍しました
# ../data/k210902.lzh を解凍しました
# ../data/k210916.lzh を解凍しました
# ../data/k210725.lzh を解凍しました
# ../data/k210731.lzh を解凍しました
# ../data/k220802.lzh を解凍しました
# ../data/k210719.lzh を解凍しました
# ../data/k220816.lzh を解凍しました
# ../data/k220814.lzh を解凍しました
# ../data/k210727.lzh を解凍しました
# ../data/k220828.lzh を解凍しました
# ../data/k210914.lzh を解凍しました
# ../data/k220627.lzh を解凍しました
# ../data/k210928.lzh を解凍しました
# ../data/k210519.lzh を解凍しました
# ../data/k210525.lzh を解凍しました
# ../data/k200722.lzh を解凍しました
# ../data/k210531.lzh を解凍しました
# ../data/k220419.lzh を解凍しました
# ../data/k200911.lzh を解凍しました
# ../data/k200905.lzh を解凍しました
# ../data/k220425.lzh を解凍しました
# ../data/k211015.lzh を解凍しました
# ../data/k201206.lzh を解凍しました
# ../data/k211001.lzh を解凍しました
# ../data/k201212.lzh を解凍しました
# ../data/k211029.lzh を解凍しました
# ../data/k210323.lzh を解凍しました
# ../data/k221115.lzh を解凍しました
# ../data/k221101.lzh を解凍しました
# ../data/k220223.lzh を解凍しました
# ../data/k210109.lzh を解凍しました
# ../data/k201004.lzh を解凍しました
# ../data/k211217.lzh を解凍しました
# ../data/k201010.lzh を解凍しました
# ../data/k211203.lzh を解凍しました
# ../data/k210121.lzh を解凍しました
# ../data/k210120.lzh を解凍しました
# ../data/k211202.lzh を解凍しました
# ../data/k201011.lzh を解凍しました
# ../data/k211216.lzh を解凍しました
# ../data/k201005.lzh を解凍しました
# ../data/k210108.lzh を解凍しました
# ../data/k220222.lzh を解凍しました
# ../data/k221114.lzh を解凍しました
# ../data/k210322.lzh を解凍しました
# ../data/k211028.lzh を解凍しました
# ../data/k201213.lzh を解凍しました
# ../data/k201207.lzh を解凍しました
# ../data/k211014.lzh を解凍しました
# ../data/k220430.lzh を解凍しました
# ../data/k220424.lzh を解凍しました
# ../data/k200904.lzh を解凍しました
# ../data/k200910.lzh を解凍しました
# ../data/k220418.lzh を解凍しました
# ../data/k210530.lzh を解凍しました
# ../data/k200723.lzh を解凍しました
# ../data/k210524.lzh を解凍しました
# ../data/k210518.lzh を解凍しました
# ../data/k210929.lzh を解凍しました
# ../data/k220626.lzh を解凍しました
# ../data/k210915.lzh を解凍しました
# ../data/k210901.lzh を解凍しました
# ../data/k220829.lzh を解凍しました
# ../data/k210726.lzh を解凍しました
# ../data/k220815.lzh を解凍しました
# ../data/k220801.lzh を解凍しました
# 作業を終了しました

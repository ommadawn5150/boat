# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
import json
import sys
import glob 
pd.set_option('display.max_columns', None)
# %load_ext autoreload
# %autoreload 2
sys.path.append('../boat/')
sys.path.append('../')
import pickle

# %%
with open('../data/pickle/df17.pkl', 'rb') as f:
    df'[]\' = pickle.load(f)

# %%
df
# Out:
#          艇番  選手登番  年齢  体重  級別  全国勝率  全国2連率  当地勝率  当地2連率  モーター2連率  ボート2連率  \
# 0         1  4096  35  54   4  6.41  44.44  7.45  59.89    24.53   33.71
# 1         2  4226  34  53   2  4.81  32.94  4.80  22.86    31.18   23.81
# 2         3  4669  31  53   1  3.17   8.70  2.58   4.17    32.20   35.56
# 3         4  4588  25  55   2  4.51  26.19  4.58  27.78    39.68   30.34
# 4         5  3875  40  51   2  5.35  36.36  4.29  25.00    36.76   33.33
# ...      ..   ...  ..  ..  ..   ...    ...   ...    ...      ...     ...
# 2474528   2  4538  33  53   3  5.67  35.87  4.57  21.74    30.65   32.21
# 2474529   3  4203  41  52   2  4.29  25.45  4.60  28.33    33.97   23.57
# 2474530   4  4905  29  53   2  4.64  26.60  0.00   0.00    37.06   43.54
# 2474531   5  4034  45  55   2  3.67  13.33  4.00  22.22    30.83   30.20
# 2474532   6  4821  32  56   2  5.82  40.66  4.92  33.33    28.37   27.70
#
#          今節成績11  今節成績12  今節成績21  今節成績22  今節成績31  今節成績32  今節成績41  今節成績42  \
# ...
